# %% [markdown]
# # Fold = 1 & Scaling 1 추론

# %%
# !pwd
# Out:
# /project/dsml2022/inhovation97/code_for_paper

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_1_scaling1_test_change, date_code_lst = load_data( fold = 1, scaling = 1 )
# Out:
# --- 31.97950053215027 seconds ---
# --- 25.13626980781555 seconds ---
# (67259, 550) (27683, 550)
# 권장 scale_pos_weight : 6.832654011878421
# 1번째 fold의 1번 스케일링 데이터가 준비되었습니다.

# %%
fold_1_scaling1_train_pred, fold_1_scaling1_train_prob, fold_1_scaling1_test_pred , fold_1_scaling1_test_prob = train_model_and_inference(1, trainX, trainY, testX, testY)
# Out:
# 1번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.612088	valid_0's binary_logloss: 0.649723
# [10]	valid_0's auc: 0.619446	valid_0's binary_logloss: 0.627696
# [15]	valid_0's auc: 0.622455	valid_0's binary_logloss: 0.613222
# [20]	valid_0's auc: 0.62587	valid_0's binary_logloss: 0.604567
# [25]	valid_0's auc: 0.627507	valid_0's binary_logloss: 0.598347
# [30]	valid_0's auc: 0.627809	valid_0's binary_logloss: 0.594349
# [35]	valid_0's auc: 0.629868	valid_0's binary_logloss: 0.590028
# [40]	valid_0's auc: 0.630932	valid_0's binary_logloss: 0.585904
# [45]	valid_0's auc: 0.631038	valid_0's binary_logloss: 0.582818
# [50]	valid_0's auc: 0.630888	valid_0's binary_logloss: 0.57968
# [55]	valid_0's auc: 0.630649	valid_0's binary_logloss: 0.577356
# [60]	valid_0's auc: 0.630405	valid_0's binary_logloss: 0.574312
# [65]	valid_0's auc: 0.630079	valid_0's binary_logloss: 0.572023
# train_f1 score:  0.3446738022426096
# test_f1 score:  0.22524958402662226
#
# train_recall score:  0.6300221264702457
# test_recall score:  0.389568345323741
#
# train_pre score:  0.23722867792150845
# test_pre score:  0.15842598010532474
#
# train acc score:  0.6941375875347537
# test acc score:  0.7308817685944442
#
#      y_true
# pred [1083, 5753]
#      [1697, 19150]
# ---1.7060623168945312 seconds ---

# %%
plot_distribute(fold_1_scaling1_test_prob, fold_1_scaling1_test_change)
# Out:
# 평균 값: 0.0016148416800399919
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.8 이상 구간의 정밀도 : 0.6382978723404256
# <AxesSubplot:xlabel='Change', ylabel='prob'>

# %% [markdown]
# # Fold = 1 & Scaling 2 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_1_scaling2_test_change, date_code_lst = load_data( fold = 1, scaling = 2 )
# Out:
# --- 34.69458198547363 seconds ---
# --- 27.875451803207397 seconds ---
# (67259, 550) (27682, 550)
# 권장 scale_pos_weight : 6.832654011878421
# 1번째 fold의 2번 스케일링 데이터가 준비되었습니다.

# %%
fold_1_scaling2_train_pred, fold_1_scaling2_train_prob, fold_1_scaling2_test_pred , fold_1_scaling2_test_prob = train_model_and_inference(1, trainX, trainY, testX, testY)
# Out:
# 1번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.625462	valid_0's binary_logloss: 0.645582
# [10]	valid_0's auc: 0.627276	valid_0's binary_logloss: 0.622763
# [15]	valid_0's auc: 0.629138	valid_0's binary_logloss: 0.609187
# [20]	valid_0's auc: 0.630606	valid_0's binary_logloss: 0.601322
# [25]	valid_0's auc: 0.632256	valid_0's binary_logloss: 0.595622
# [30]	valid_0's auc: 0.633093	valid_0's binary_logloss: 0.591157
# [35]	valid_0's auc: 0.633488	valid_0's binary_logloss: 0.586321
# [40]	valid_0's auc: 0.633475	valid_0's binary_logloss: 0.583273
# [45]	valid_0's auc: 0.63402	valid_0's binary_logloss: 0.580563
# [50]	valid_0's auc: 0.634492	valid_0's binary_logloss: 0.575887
# [55]	valid_0's auc: 0.635018	valid_0's binary_logloss: 0.573729
# [60]	valid_0's auc: 0.635469	valid_0's binary_logloss: 0.571639
# [65]	valid_0's auc: 0.6353	valid_0's binary_logloss: 0.569496
# [70]	valid_0's auc: 0.635011	valid_0's binary_logloss: 0.567448
# [75]	valid_0's auc: 0.634162	valid_0's binary_logloss: 0.565841
# [80]	valid_0's auc: 0.634575	valid_0's binary_logloss: 0.563271
# [85]	valid_0's auc: 0.635253	valid_0's binary_logloss: 0.561268
# train_f1 score:  0.348273959163652
# test_f1 score:  0.23003008832378918
#
# train_recall score:  0.6614650052404798
# test_recall score:  0.4262589928057554
#
# train_pre score:  0.23636136656818277
# test_pre score:  0.15751694802605343
#
# train acc score:  0.6839382090129202
# test acc score:  0.7134238855574019
#
#      y_true
# pred [1185, 6338]
#      [1595, 18564]
# ---1.4872708320617676 seconds ---

# %%
plot_distribute(fold_1_scaling2_test_prob, fold_1_scaling2_test_change)
# Out:
# 평균 값: 0.0016147036863643667
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.8 이상 구간의 정밀도 : 0.6619718309859155
# <AxesSubplot:xlabel='Change', ylabel='prob'>

# %% [markdown]
# # Fold = 1 & Scaling 3 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, fold_1_scaling3_test_change, test_change, date_code_lst = load_data( fold = 1, scaling = 3 )
# Out:
# --- 33.47734355926514 seconds ---
# --- 24.705284595489502 seconds ---
# (67259, 550) (27683, 550)
# 권장 scale_pos_weight : 6.832654011878421
# 1번째 fold의 3번 스케일링 데이터가 준비되었습니다.

# %%
fold_1_scaling3_train_pred, fold_1_scaling3_train_prob, fold_1_scaling3_test_pred , fold_1_scaling3_test_prob = train_model_and_inference(1, trainX, trainY, testX, testY)
# Out:
# 1번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.611445	valid_0's binary_logloss: 0.63694
# [10]	valid_0's auc: 0.62323	valid_0's binary_logloss: 0.608394
# [15]	valid_0's auc: 0.62984	valid_0's binary_logloss: 0.591915
# [20]	valid_0's auc: 0.631349	valid_0's binary_logloss: 0.580959
# [25]	valid_0's auc: 0.633386	valid_0's binary_logloss: 0.574004
# [30]	valid_0's auc: 0.634552	valid_0's binary_logloss: 0.568636
# [35]	valid_0's auc: 0.632934	valid_0's binary_logloss: 0.564786
# [40]	valid_0's auc: 0.633807	valid_0's binary_logloss: 0.561235
# [45]	valid_0's auc: 0.633967	valid_0's binary_logloss: 0.55832
# [50]	valid_0's auc: 0.634687	valid_0's binary_logloss: 0.555556
# [55]	valid_0's auc: 0.634045	valid_0's binary_logloss: 0.553104
# [60]	valid_0's auc: 0.633939	valid_0's binary_logloss: 0.550353
# [65]	valid_0's auc: 0.63321	valid_0's binary_logloss: 0.548398
# [70]	valid_0's auc: 0.633294	valid_0's binary_logloss: 0.547052
# [75]	valid_0's auc: 0.633595	valid_0's binary_logloss: 0.545236
# train_f1 score:  0.3615550041356493
# test_f1 score:  0.2320429370789083
#
# train_recall score:  0.6363107022242925
# test_recall score:  0.36546762589928056
#
# train_pre score:  0.2525187170718181
# test_pre score:  0.16998494227873515
#
# train acc score:  0.7130941584025929
# test acc score:  0.7570711266842467
#
#      y_true
# pred [1016, 4961]
#      [1764, 19942]
# ---1.4246368408203125 seconds ---

# %%
plot_distribute(fold_1_scaling3_test_prob, fold_1_scaling3_test_change)
# Out:
# 평균 값: 0.0032609134761944812
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.8 이상 구간의 정밀도 : 0.8478260869565217
# <AxesSubplot:xlabel='Change', ylabel='prob'>

# %% [markdown]
# # Fold = 1 & Scaling 4 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_1_scaling4_test_change, date_code_lst = load_data( fold = 1, scaling = 4 )
# Out:
# --- 32.57253456115723 seconds ---
# --- 23.964292526245117 seconds ---
# (67259, 550) (27683, 550)
# 권장 scale_pos_weight : 6.832654011878421
# 1번째 fold의 4번 스케일링 데이터가 준비되었습니다.

# %%
fold_1_scaling4_train_pred, fold_1_scaling4_train_prob, fold_1_scaling4_test_pred , fold_1_scaling4_test_prob = train_model_and_inference(1, trainX, trainY, testX, testY)
# Out:
# 1번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.614132	valid_0's binary_logloss: 0.640487
# [10]	valid_0's auc: 0.626785	valid_0's binary_logloss: 0.613775
# [15]	valid_0's auc: 0.627886	valid_0's binary_logloss: 0.59587
# [20]	valid_0's auc: 0.628562	valid_0's binary_logloss: 0.584719
# [25]	valid_0's auc: 0.630471	valid_0's binary_logloss: 0.576099
# [30]	valid_0's auc: 0.629269	valid_0's binary_logloss: 0.568609
# [35]	valid_0's auc: 0.628779	valid_0's binary_logloss: 0.56455
# [40]	valid_0's auc: 0.629801	valid_0's binary_logloss: 0.561015
# [45]	valid_0's auc: 0.630385	valid_0's binary_logloss: 0.558153
# [50]	valid_0's auc: 0.630496	valid_0's binary_logloss: 0.555724
# [55]	valid_0's auc: 0.629517	valid_0's binary_logloss: 0.553442
# [60]	valid_0's auc: 0.629962	valid_0's binary_logloss: 0.551069
# [65]	valid_0's auc: 0.631215	valid_0's binary_logloss: 0.548107
# [70]	valid_0's auc: 0.630314	valid_0's binary_logloss: 0.546362
# [75]	valid_0's auc: 0.630051	valid_0's binary_logloss: 0.544423
# [80]	valid_0's auc: 0.630284	valid_0's binary_logloss: 0.543166
# [85]	valid_0's auc: 0.630057	valid_0's binary_logloss: 0.540785
# [90]	valid_0's auc: 0.630584	valid_0's binary_logloss: 0.539204
# train_f1 score:  0.36546277632752866
# test_f1 score:  0.23113045470163784
#
# train_recall score:  0.6439967392570164
# test_recall score:  0.36294964028776977
#
# train_pre score:  0.25512087100941133
# test_pre score:  0.1695513359099311
#
# train acc score:  0.7144917408822611
# test acc score:  0.7575046057146986
#
#      y_true
# pred [1009, 4942]
#      [1771, 19961]
# ---1.514763593673706 seconds ---

# %%
plot_distribute(fold_1_scaling4_test_prob, fold_1_scaling4_test_change)
# Out:
# 평균 값: 0.0016148416800399919
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.8 이상 구간의 정밀도 : 0.5833333333333334
# <AxesSubplot:xlabel='Change', ylabel='prob'>

# %% [markdown]
# # Fold = 2 & Scaling 1 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_2_scaling1_test_change, date_code_lst = load_data( fold = 2, scaling = 1 )
# Out:
# --- 32.53612232208252 seconds ---
# --- 22.547688484191895 seconds ---
# (81385, 550) (28430, 550)
# 권장 scale_pos_weight : 6.416841337829217
# 2번째 fold의 1번 스케일링 데이터가 준비되었습니다.

# %%
fold_2_scaling1_train_pred, fold_2_scaling1_train_prob, fold_2_scaling1_test_pred , fold_2_scaling1_test_prob = train_model_and_inference(2, trainX, trainY, testX, testY)
# Out:
# 2번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.603266	valid_0's binary_logloss: 0.668718
# [10]	valid_0's auc: 0.607954	valid_0's binary_logloss: 0.657262
# [15]	valid_0's auc: 0.613934	valid_0's binary_logloss: 0.649137
# [20]	valid_0's auc: 0.613777	valid_0's binary_logloss: 0.643383
# [25]	valid_0's auc: 0.61274	valid_0's binary_logloss: 0.640024
# [30]	valid_0's auc: 0.6155	valid_0's binary_logloss: 0.6367
# [35]	valid_0's auc: 0.615267	valid_0's binary_logloss: 0.634395
# [40]	valid_0's auc: 0.615819	valid_0's binary_logloss: 0.63087
# [45]	valid_0's auc: 0.615237	valid_0's binary_logloss: 0.628774
# [50]	valid_0's auc: 0.616009	valid_0's binary_logloss: 0.62568
# [55]	valid_0's auc: 0.616675	valid_0's binary_logloss: 0.624133
# [60]	valid_0's auc: 0.616826	valid_0's binary_logloss: 0.62156
# [65]	valid_0's auc: 0.617293	valid_0's binary_logloss: 0.619062
# [70]	valid_0's auc: 0.616666	valid_0's binary_logloss: 0.615851
# [75]	valid_0's auc: 0.616978	valid_0's binary_logloss: 0.614424
# train_f1 score:  0.3519089802733988
# test_f1 score:  0.243915437910819
#
# train_recall score:  0.5665724961268568
# test_recall score:  0.41974931213696115
#
# train_pre score:  0.2552134646962233
# test_pre score:  0.17190434455990986
#
# train acc score:  0.7186336548504024
# test acc score:  0.7005979599015125
#
#      y_true
# pred [1373, 6614]
#      [1898, 18545]
# ---1.6402580738067627 seconds ---

# %%
plot_distribute(fold_2_scaling1_test_prob, fold_2_scaling1_test_change)
# Out:
# 평균 값: 0.0023146180238369893
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.8 이상 구간의 정밀도 : 0.7567567567567568
# <AxesSubplot:xlabel='Change', ylabel='prob'>

# %% [markdown]
# # Fold = 2 & Scaling 2 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_2_scaling2_test_change, date_code_lst = load_data( fold = 2, scaling = 2 )
# Out:
# --- 37.17855715751648 seconds ---
# --- 24.77049994468689 seconds ---
# (81252, 550) (28397, 550)
# 권장 scale_pos_weight : 6.4148567256798685
# 2번째 fold의 2번 스케일링 데이터가 준비되었습니다.

# %%
fold_2_scaling2_train_pred, fold_2_scaling2_train_prob, fold_2_scaling2_test_pred , fold_2_scaling2_test_prob = train_model_and_inference(2, trainX, trainY, testX, testY)
# Out:
# 2번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.629868	valid_0's binary_logloss: 0.657186
# [10]	valid_0's auc: 0.630773	valid_0's binary_logloss: 0.639236
# [15]	valid_0's auc: 0.633808	valid_0's binary_logloss: 0.62888
# [20]	valid_0's auc: 0.635164	valid_0's binary_logloss: 0.622342
# [25]	valid_0's auc: 0.63565	valid_0's binary_logloss: 0.618249
# [30]	valid_0's auc: 0.635774	valid_0's binary_logloss: 0.614949
# [35]	valid_0's auc: 0.635766	valid_0's binary_logloss: 0.611508
# [40]	valid_0's auc: 0.636022	valid_0's binary_logloss: 0.609
# [45]	valid_0's auc: 0.635738	valid_0's binary_logloss: 0.606892
# [50]	valid_0's auc: 0.63598	valid_0's binary_logloss: 0.604696
# [55]	valid_0's auc: 0.636846	valid_0's binary_logloss: 0.602501
# [60]	valid_0's auc: 0.638	valid_0's binary_logloss: 0.60113
# [65]	valid_0's auc: 0.638349	valid_0's binary_logloss: 0.599353
# [70]	valid_0's auc: 0.638314	valid_0's binary_logloss: 0.59814
# [75]	valid_0's auc: 0.637907	valid_0's binary_logloss: 0.596948
# [80]	valid_0's auc: 0.637855	valid_0's binary_logloss: 0.595029
# [85]	valid_0's auc: 0.637599	valid_0's binary_logloss: 0.593082
# [90]	valid_0's auc: 0.637667	valid_0's binary_logloss: 0.592392
# train_f1 score:  0.3652197877910982
# test_f1 score:  0.2578176047792402
#
# train_recall score:  0.6046723854718015
# test_recall score:  0.4225826193390453
#
# train_pre score:  0.26161803608796935
# test_pre score:  0.1854936198791135
#
# train acc score:  0.7165239009501304
# test acc score:  0.7200056343979998
#
#      y_true
# pred [1381, 6064]
#      [1887, 19065]
# ---1.8070499897003174 seconds ---

# %%
plot_distribute(fold_2_scaling2_test_prob, fold_2_scaling2_test_change)
# Out:
# 평균 값: 0.002330534533743602
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.8 이상 구간의 정밀도 : 0.6585365853658537
# <AxesSubplot:xlabel='Change', ylabel='prob'>

# %% [markdown]
# # Fold = 2 & Scaling 3 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_2_scaling3_test_change, date_code_lst = load_data( fold = 2, scaling = 3 )
# Out:
# --- 35.400285959243774 seconds ---
# --- 26.195551872253418 seconds ---
# (81385, 550) (28430, 550)
# 권장 scale_pos_weight : 6.416841337829217
# 2번째 fold의 3번 스케일링 데이터가 준비되었습니다.

# %%
fold_2_scaling3_train_pred, fold_2_scaling3_train_prob, fold_2_scaling3_test_pred , fold_2_scaling3_test_prob = train_model_and_inference(2, trainX, trainY, testX, testY)
# Out:
# 2번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.633082	valid_0's binary_logloss: 0.656182
# [10]	valid_0's auc: 0.638107	valid_0's binary_logloss: 0.634969
# [15]	valid_0's auc: 0.636992	valid_0's binary_logloss: 0.623939
# [20]	valid_0's auc: 0.637693	valid_0's binary_logloss: 0.616817
# [25]	valid_0's auc: 0.638239	valid_0's binary_logloss: 0.611687
# [30]	valid_0's auc: 0.63841	valid_0's binary_logloss: 0.607595
# [35]	valid_0's auc: 0.639764	valid_0's binary_logloss: 0.603267
# [40]	valid_0's auc: 0.638922	valid_0's binary_logloss: 0.601079
# [45]	valid_0's auc: 0.638516	valid_0's binary_logloss: 0.598171
# [50]	valid_0's auc: 0.63864	valid_0's binary_logloss: 0.5961
# [55]	valid_0's auc: 0.638406	valid_0's binary_logloss: 0.594732
# [60]	valid_0's auc: 0.638102	valid_0's binary_logloss: 0.592693
# train_f1 score:  0.3492160569331702
# test_f1 score:  0.2580158430780838
#
# train_recall score:  0.5724049940763692
# test_recall score:  0.41822072760623663
#
# train_pre score:  0.25125005000200007
# test_pre score:  0.18655393426973954
#
# train acc score:  0.7123548565460466
# test acc score:  0.7232500879352797
#
#      y_true
# pred [1368, 5965]
#      [1903, 19194]
# ---1.5662741661071777 seconds ---

# %%
plot_distribute(fold_2_scaling3_test_prob, fold_2_scaling3_test_change)
# Out:
# 평균 값: 0.0023146180238369893
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.8 이상 구간의 정밀도 : 0.5945945945945946
# <AxesSubplot:xlabel='Change', ylabel='prob'>

# %% [markdown]
# # Fold = 2 & Scaling 4 추론

# %%
from train import load_data, train_model_and_inference
from utils import plot_distribute

trainX, trainY, testX , testY, train_change, fold_2_scaling4_test_change, date_code_lst = load_data( fold = 2, scaling = 4 )
# Out:
# --- 31.862512826919556 seconds ---
# --- 23.687320232391357 seconds ---
# (81385, 550) (28430, 550)
# 권장 scale_pos_weight : 6.416841337829217
# 2번째 fold의 4번 스케일링 데이터가 준비되었습니다.

# %%
fold_2_scaling4_train_pred, fold_2_scaling4_train_prob, fold_2_scaling4_test_pred , fold_2_scaling4_test_prob = train_model_and_inference(2, trainX, trainY, testX, testY)
# Out:
# 2번째 fold를 위한 모델이 준비되었습니다.
# [5]	valid_0's auc: 0.619952	valid_0's binary_logloss: 0.658209
# [10]	valid_0's auc: 0.62475	valid_0's binary_logloss: 0.636725
# [15]	valid_0's auc: 0.628558	valid_0's binary_logloss: 0.624068
# [20]	valid_0's auc: 0.632143	valid_0's binary_logloss: 0.61548
# [25]	valid_0's auc: 0.635031	valid_0's binary_logloss: 0.609651
# [30]	valid_0's auc: 0.636499	valid_0's binary_logloss: 0.6045
# [35]	valid_0's auc: 0.637092	valid_0's binary_logloss: 0.601439
# [40]	valid_0's auc: 0.637991	valid_0's binary_logloss: 0.597631
# [45]	valid_0's auc: 0.639674	valid_0's binary_logloss: 0.594796
# [50]	valid_0's auc: 0.639406	valid_0's binary_logloss: 0.592048
# [55]	valid_0's auc: 0.639468	valid_0's binary_logloss: 0.590245
# [60]	valid_0's auc: 0.640222	valid_0's binary_logloss: 0.58746
# [65]	valid_0's auc: 0.640966	valid_0's binary_logloss: 0.585874
# [70]	valid_0's auc: 0.639322	valid_0's binary_logloss: 0.583382
# [75]	valid_0's auc: 0.639829	valid_0's binary_logloss: 0.581685
# [80]	valid_0's auc: 0.640781	valid_0's binary_logloss: 0.580407
# [85]	valid_0's auc: 0.641023	valid_0's binary_logloss: 0.578306
# [90]	valid_0's auc: 0.640568	valid_0's binary_logloss: 0.577409
# [95]	valid_0's auc: 0.640012	valid_0's binary_logloss: 0.576775
# [100]	valid_0's auc: 0.639625	valid_0's binary_logloss: 0.574862
# [105]	valid_0's auc: 0.640088	valid_0's binary_logloss: 0.573245
# train_f1 score:  0.40006138735420504
# test_f1 score:  0.2528231553557724
#
# train_recall score:  0.5939123302651964
# test_recall score:  0.352491592785081
#
# train_pre score:  0.30161521729069285
# test_pre score:  0.19709401709401708
#
# train acc score:  0.7598328930392578
# test acc score:  0.7602884277172002
#
#      y_true
# pred [1153, 4697]
#      [2118, 20462]
# ---2.219774007797241 seconds ---

# %%
plot_distribute(fold_2_scaling4_test_prob, fold_2_scaling4_test_change)
# Out:
# 평균 값: 0.0023146180238369893
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.8 이상 구간의 정밀도 : 0.5490196078431373
# <AxesSubplot:xlabel='Change', ylabel='prob'>

# %%
fold_2_scaling4_test_change
# Out:
# array([-0.02075472, -0.09232481, -0.00857843, ...,  0.00766284,
#         0.00413223, -0.02864583])

# %%
label_0_lst=[]
label_1_lst=[]

for value in fold_2_scaling4_test_change:
    if value >= 0.05:
        label_1_lst.append(value)
    
    else:
        label_0_lst.append(value)

# %%
'''plt.xticks 에러 먹음 -30~30으로 바꿔줘야 함'''
import matplotlib.pyplot as plt
import seaborn as sns

ax=plt.figure(figsize=(12,6))
ax=sns.histplot(label_0_lst, bins = 35, label = 'label 0')
ax=sns.histplot(label_1_lst, bins=25, color = 'r', label = 'label 1')
# plt.xticks(fontsize=15)

ax.set_xlabel('Change', fontsize=15)
ax.legend(fontsize=15)
# ax = plt.axvline(np.mean(fold_2_scaling4_test_change), linewidth=2, color = 'red')
# xtick_lst = np.array([-0.3, -0.2, -0.05, np.mean(fold_2_scaling4_test_change), 0.05, 0.2, 0.3])

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

fold_1prob_data =[fold_1_scaling1_test_prob, fold_1_scaling2_test_prob,fold_1_scaling3_test_prob,fold_1_scaling4_test_prob]
fold_1change_data =[fold_1_scaling1_test_change, fold_1_scaling2_test_change, fold_1_scaling3_test_change, fold_1_scaling4_test_change]

data_lst = []

for i in range(4):
    if i== 0:
        scaling = 'scaling1'
    elif i== 1:
        scaling = 'scaling2'
    elif i== 2:
        scaling = 'scaling3'
    elif i== 3:
        scaling = 'scaling4'
    for prob, change in zip(fold_1prob_data[i],fold_1change_data[i]):
        if prob >= 0.8:
            data_lst.append([scaling, prob, change, 1])
        elif 0.6 <= prob < 0.8:
            data_lst.append([scaling, prob, change, 2])
        elif 0.4 <= prob < 0.6:
            data_lst.append([scaling, prob, change, 3])
        elif 0.2 <= prob < 0.4:
            data_lst.append([scaling, prob, change, 4])
        elif prob < 0.2:
            data_lst.append([scaling, prob, change, 5])
data_df = pd.DataFrame(data_lst, columns = ['scaling', 'prob', 'change', 'predict_probability'])

# %%
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

f,ax=plt.subplots(1,1,figsize=(20,12),sharex=False)
ax = sns.boxplot(data = data_df, 
                 x='scaling',
                 y='change', 
                 hue = 'predict_probability', 
                 palette = 'OrRd', 
                 hue_order = [5,4,3,2,1], 
                 )
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax.set_xlabel('')
ax.set_ylabel('change [-30 ~ +30%]', fontsize=15)
ax.legend(title='predict_probability',fontsize=13)
legend_lst = ['0~20%', '20~40%', '40~60%','60~80%', '80~100%']

plt.axhline(0, color='y', linewidth = 5)

for i,text in enumerate(legend_lst):
    ax.legend_.texts[i].set_text(text)

# %%
ax.legend_.texts[0]
# Out:
# Text(0, 0, '0~20%')

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

prob_data =[fold_2_scaling1_test_prob, fold_2_scaling2_test_prob,fold_2_scaling3_test_prob,fold_2_scaling4_test_prob]
change_data =[fold_2_scaling1_test_change, fold_2_scaling2_test_change, fold_2_scaling3_test_change, fold_2_scaling4_test_change]

data_lst = []

for i in range(4):
    if i== 0:
        scaling = 'scaling1'
    elif i== 1:
        scaling = 'scaling2'
    elif i== 2:
        scaling = 'scaling3'
    elif i== 3:
        scaling = 'scaling4'
    for prob, change in zip(prob_data[i],change_data[i]):
        if prob >= 0.8:
            data_lst.append([scaling, prob, change, 1])
        elif 0.6 <= prob < 0.8:
            data_lst.append([scaling, prob, change, 2])
        elif 0.4 <= prob < 0.6:
            data_lst.append([scaling, prob, change, 3])
        elif 0.2 <= prob < 0.4:
            data_lst.append([scaling, prob, change, 4])
        elif prob < 0.2:
            data_lst.append([scaling, prob, change, 5])
data_df = pd.DataFrame(data_lst, columns = ['scaling', 'prob', 'change', 'predict_probability'])

# %%
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

f,ax=plt.subplots(1,1,figsize=(20,12),sharex=False)
ax = sns.boxplot(data = data_df, 
                 x='scaling',
                 y='change', 
                 hue = 'predict_probability', 
                 palette = 'OrRd', 
                 hue_order = [5,4,3,2,1], 
                 )
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
ax.set_xlabel('')
ax.set_ylabel('change [-30 ~ +30%]', fontsize=15)
ax.legend(title='predict_probability',fontsize=13)
legend_lst = ['0~20%', '20~40%', '40~60%','60~80%', '80~100%']

plt.axhline(0, color='y', linewidth = 5)

for i,text in enumerate(legend_lst):
    ax.legend_.texts[i].set_text(text)

# %%
import pandas as pd
f2_s4_80_label_0=[]
f2_s4_80_label_1=[]
data = []
for prob,change in zip(fold_2_scaling4_test_prob, fold_2_scaling4_test_change):
    if prob >= 0.8 and change >= 0.05:
        f2_s4_80_label_1.append(change)
        data.append(change)
        
    elif prob >= 0.8 and change < 0.05:
        f2_s4_80_label_0.append(change)
        data.append(change)
data = (pd.Series(data) >= 0.05).value_counts(ascending=True)

# %%
f, ax = plt.subplots(1,1,figsize=(12,6),sharex=False)


title = 'predited_imbalance_pie_chart'
labels = ['label 1', 'label 0']
ax.pie( data, colors = ['firebrick','steelblue'],
                                         startangle=90,
                                         autopct = '%1.2f%%', 
                                         labels=labels)
plt.legend(fontsize=15)

# %%
len(f2_s4_80_label_0)
# Out:
# 28

# %%
len(f2_s4_80_label_1)
# Out:
# 23

# %%
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
ax=plt.figure(figsize=(12,6))
ax = sns.histplot(f2_s4_80_label_0,bins = 14, label = 'label 0')
ax = sns.histplot(f2_s4_80_label_1,bins = 20, color='r', label = 'label 1')
plt.legend(fontsize=20)

# %%
sns.histplot(f2_s4_80_label_1, bins = 25, color='r')
sns.histplot(f2_s4_80_label_0, bins = 35)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# # 시뮬레이션 인덱스 플롯

# %%
from simulator import simulator
fold=2
for i,test_prob in enumerate(prob_data):
    if i ==0:
        scaling1_simul = simulator( date_code_lst, test_prob, fold )
    elif i==1:
        scaling2_simul = simulator( date_code_lst, test_prob, fold )
    elif i==2:
        scaling3_simul = simulator( date_code_lst, test_prob, fold )
    elif i==3:
        scaling4_simul = simulator( date_code_lst, test_prob, fold )
# Out:
# 시작 금액 : 100.0 만원
#
# 2021-02-15 : BUY 051980 -> 293주 구입, 매수 금액: 49.9565만원
# 2021-02-15 : BUY 004140 -> 51주 구입, 매수 금액: 49.0518만원
# 2021-02-16 : SELL 051980 -> 매도 금액 : 52.447만원, 전날 대비 상승률 0.04985337243401755:, 이익금 : 2.4905만원, 현재 자산 : 53.44만원
# 2021-02-16 : SELL 004140 -> 매도 금액 : 63.7143만원, 전날 대비 상승률 0.29891869411520067:, 이익금 : 14.6625만원, 현재 자산 : 117.15만원
#
# 2021-03-08 : BUY 009620 -> 960주 구입, 매수 금액: 117.12만원
# 2021-03-09 : SELL 009620 -> 매도 금액 : 121.44만원, 전날 대비 상승률 0.03688524590163933:, 이익금 : 4.32만원, 현재 자산 : 121.47만원
#
# 2021-03-11 : BUY 049080 -> 742주 구입, 매수 금액: 121.317만원
# 2021-03-12 : SELL 049080 -> 매도 금액 : 126.14만원, 전날 대비 상승률 0.039755351681957096:, 이익금 : 4.823만원, 현재 자산 : 126.30만원
#
# 2021-03-15 : BUY 053030 -> 78주 구입, 매수 금액: 125.97만원
# 2021-03-16 : SELL 053030 -> 매도 금액 : 154.44만원, 전날 대비 상승률 0.22600619195046434:, 이익금 : 28.47만원, 현재 자산 : 154.77만원
#
# 2021-03-22 : BUY 089530 -> 479주 구입, 매수 금액: 154.7649만원
# 2021-03-23 : SELL 089530 -> 매도 금액 : 141.4966만원, 전날 대비 상승률 -0.08573197152584344:, 이익금 : -13.2683만원, 현재 자산 : 141.50만원
#
# 2021-03-23 : BUY 089530 -> 479주 구입, 매수 금액: 141.4966만원
# 2021-03-24 : SELL 089530 -> 매도 금액 : 144.6101만원, 전날 대비 상승률 0.022004062288422555:, 이익금 : 3.1135만원, 현재 자산 : 144.61만원
#
# 2021-03-26 : BUY 065500 -> 218주 구입, 매수 금액: 72.0054만원
# 2021-03-26 : BUY 064090 -> 174주 구입, 매수 금액: 71.8968만원
# 2021-03-29 : SELL 065500 -> 매도 금액 : 81.5756만원, 전날 대비 상승률 0.13290947623372684:, 이익금 : 9.5702만원, 현재 자산 : 82.28만원
# 2021-03-29 : SELL 064090 -> 매도 금액 : 67.512만원, 전날 대비 상승률 -0.06098741529525653:, 이익금 : -4.3848만원, 현재 자산 : 149.80만원
#
# 2021-03-30 : BUY 065500 -> 331주 구입, 매수 금액: 149.7775만원
# 2021-03-31 : SELL 065500 -> 매도 금액 : 173.7419만원, 전날 대비 상승률 0.15999999999999992:, 이익금 : 23.9644만원, 현재 자산 : 173.76만원
#
# 2021-04-01 : BUY 064090 -> 416주 구입, 매수 금액: 173.472만원
# 2021-04-02 : SELL 064090 -> 매도 금액 : 168.7296만원, 전날 대비 상승률 -0.027338129496402908:, 이익금 : -4.7424만원, 현재 자산 : 169.02만원
#
# 2021-04-06 : BUY 224060 -> 7192주 구입, 매수 금액: 169.012만원
# 2021-04-07 : SELL 224060 -> 매도 금액 : 166.1352만원, 전날 대비 상승률 -0.017021276595744705:, 이익금 : -2.8768만원, 현재 자산 : 166.14만원
#
# 2021-05-18 : BUY 139670 -> 59주 구입, 매수 금액: 165.2만원
# 2021-05-20 : SELL 139670 -> 매도 금액 : 132.455만원, 전날 대비 상승률 -0.19821428571428568:, 이익금 : -32.745만원, 현재 자산 : 133.40만원
#
# 2021-05-24 : BUY 139670 -> 66주 구입, 매수 금액: 131.67만원
# 2021-05-25 : SELL 139670 -> 매도 금액 : 133.98만원, 전날 대비 상승률 0.01754385964912286:, 이익금 : 2.31만원, 현재 자산 : 135.71만원
#
# 2021-05-25 : BUY 032860 -> 199주 구입, 매수 금액: 135.519만원
# 2021-05-26 : SELL 032860 -> 매도 금액 : 176.115만원, 전날 대비 상승률 0.2995594713656389:, 이익금 : 40.596만원, 현재 자산 : 176.30만원
#
# 2021-05-26 : BUY 139670 -> 41주 구입, 매수 금액: 88.15만원
# 2021-05-26 : BUY 032860 -> 99주 구입, 매수 금액: 87.615만원
# 2021-05-27 : SELL 139670 -> 매도 금액 : 84.255만원, 전날 대비 상승률 -0.04418604651162794:, 이익금 : -3.895만원, 현재 자산 : 84.79만원
# 2021-05-27 : SELL 032860 -> 매도 금액 : 92.07만원, 전날 대비 상승률 0.05084745762711873:, 이익금 : 4.455만원, 현재 자산 : 176.86만원
#
# 2021-06-01 : BUY 101390 -> 143주 구입, 매수 금액: 175.8328만원
# 2021-06-02 : SELL 101390 -> 매도 금액 : 192.4065만원, 전날 대비 상승률 0.09425829538061148:, 이익금 : 16.5737만원, 현재 자산 : 193.44만원
#
# 2021-06-29 : BUY 121850 -> 610주 구입, 매수 금액: 193.37만원
# 2021-06-30 : SELL 121850 -> 매도 금액 : 197.945만원, 전날 대비 상승률 0.023659305993690927:, 이익금 : 4.575만원, 현재 자산 : 198.01만원
#
# 2021-07-02 : BUY 121850 -> 661주 구입, 매수 금액: 197.9695만원
# 2021-07-05 : SELL 121850 -> 매도 금액 : 198.961만원, 전날 대비 상승률 0.005008347245408995:, 이익금 : 0.9915만원, 현재 자산 : 199.00만원
#
# 2021-08-17 : BUY 019490 -> 488주 구입, 매수 금액: 198.86만원
# 2021-08-18 : SELL 019490 -> 매도 금액 : 198.86만원, 전날 대비 상승률 0.0:, 이익금 : 0.0만원, 현재 자산 : 199.00만원
#
# 2021-08-20 : BUY 065440 -> 637주 구입, 매수 금액: 198.744만원
# 2021-08-23 : SELL 065440 -> 매도 금액 : 196.833만원, 전날 대비 상승률 -0.009615384615384581:, 이익금 : -1.911만원, 현재 자산 : 197.09만원
#
# 2021-09-14 : BUY 042040 -> 1296주 구입, 매수 금액: 196.992만원
# 2021-09-15 : SELL 042040 -> 매도 금액 : 195.048만원, 전날 대비 상승률 -0.009868421052631526:, 이익금 : -1.944만원, 현재 자산 : 195.15만원
#
# 2021-09-24 : BUY 042040 -> 1223주 구입, 매수 금액: 195.0685만원
# 2021-09-27 : SELL 042040 -> 매도 금액 : 183.45만원, 전날 대비 상승률 -0.059561128526645746:, 이익금 : -11.6185만원, 현재 자산 : 183.53만원
#
# 2021-10-06 : BUY 208710 -> 316주 구입, 매수 금액: 91.64만원
# 2021-10-06 : BUY 020180 -> 635주 구입, 매수 금액: 91.7575만원
# 2021-10-07 : SELL 208710 -> 매도 금액 : 103.964만원, 전날 대비 상승률 0.1344827586206896:, 이익금 : 12.324만원, 현재 자산 : 104.10만원
# 2021-10-07 : SELL 020180 -> 매도 금액 : 97.155만원, 전날 대비 상승률 0.05882352941176472:, 이익금 : 5.3975만원, 현재 자산 : 201.25만원
#
# 2021-10-07 : BUY 002290 -> 177주 구입, 매수 금액: 100.182만원
# 2021-10-07 : BUY 020180 -> 657주 구입, 매수 금액: 100.521만원
# 2021-10-08 : SELL 002290 -> 매도 금액 : 101.775만원, 전날 대비 상승률 0.01590106007067127:, 이익금 : 1.593만원, 현재 자산 : 102.32만원
# 2021-10-08 : SELL 020180 -> 매도 금액 : 102.8205만원, 전날 대비 상승률 0.02287581699346397:, 이익금 : 2.2995만원, 현재 자산 : 205.14만원
#
# 2021-10-12 : BUY 002290 -> 202주 구입, 매수 금액: 102.212만원
# 2021-10-12 : BUY 020180 -> 743주 구입, 매수 금액: 102.534만원
# 2021-10-13 : SELL 002290 -> 매도 금액 : 103.222만원, 전날 대비 상승률 0.009881422924901129:, 이익금 : 1.01만원, 현재 자산 : 103.62만원
# 2021-10-13 : SELL 020180 -> 매도 금액 : 107.3635만원, 전날 대비 상승률 0.047101449275362306:, 이익금 : 4.8295만원, 현재 자산 : 210.98만원
#
# 2021-10-18 : BUY 185490 -> 86주 구입, 매수 금액: 210.7만원
# 2021-10-19 : SELL 185490 -> 매도 금액 : 211.99만원, 전날 대비 상승률 0.00612244897959191:, 이익금 : 1.29만원, 현재 자산 : 212.27만원
#
# 2021-11-05 : BUY 025550 -> 447주 구입, 매수 금액: 211.878만원
# 2021-11-08 : SELL 025550 -> 매도 금액 : 201.3735만원, 전날 대비 상승률 -0.04957805907172996:, 이익금 : -10.5045만원, 현재 자산 : 201.77만원
#
# 2021-11-08 : BUY 039240 -> 464주 구입, 매수 금액: 201.376만원
# 2021-11-09 : SELL 039240 -> 매도 금액 : 193.488만원, 전날 대비 상승률 -0.03917050691244239:, 이익금 : -7.888만원, 현재 자산 : 193.88만원
#
# 2021-11-09 : BUY 060560 -> 1551주 구입, 매수 금액: 193.875만원
# 2021-11-10 : SELL 060560 -> 매도 금액 : 195.426만원, 전날 대비 상승률 0.008000000000000007:, 이익금 : 1.551만원, 현재 자산 : 195.43만원
#
# 2021-11-10 : BUY 033830 -> 1588주 구입, 매수 금액: 195.324만원
# 2021-11-11 : SELL 033830 -> 매도 금액 : 191.354만원, 전날 대비 상승률 -0.020325203252032575:, 이익금 : -3.97만원, 현재 자산 : 191.46만원
#
# 2021-11-11 : BUY 189860 -> 216주 구입, 매수 금액: 191.16만원
# 2021-11-12 : SELL 189860 -> 매도 금액 : 195.048만원, 전날 대비 상승률 0.02033898305084736:, 이익금 : 3.888만원, 현재 자산 : 195.35만원
#
# 2021-11-12 : BUY 032280 -> 731주 구입, 매수 금액: 195.177만원
# 2021-11-15 : SELL 032280 -> 매도 금액 : 196.639만원, 전날 대비 상승률 0.0074906367041198685:, 이익금 : 1.462만원, 현재 자산 : 196.81만원
#
#  earning_rate : 196.8115
# 시작 금액 : 100.0 만원
#
# 2021-01-04 : BUY 083420 -> 91주 구입, 매수 금액: 99.645만원
# 2021-01-05 : SELL 083420 -> 매도 금액 : 96.915만원, 전날 대비 상승률 -0.0273972602739726:, 이익금 : -2.73만원, 현재 자산 : 97.27만원
#
# 2021-01-26 : BUY 004560 -> 58주 구입, 매수 금액: 95.7만원
# 2021-01-27 : SELL 004560 -> 매도 금액 : 124.41만원, 전날 대비 상승률 0.30000000000000004:, 이익금 : 28.71만원, 현재 자산 : 125.98만원
#
# 2021-02-15 : BUY 051980 -> 738주 구입, 매수 금액: 125.829만원
# 2021-02-16 : SELL 051980 -> 매도 금액 : 132.102만원, 전날 대비 상승률 0.04985337243401755:, 이익금 : 6.273만원, 현재 자산 : 132.25만원
#
# 2021-02-16 : BUY 044480 -> 616주 구입, 매수 금액: 132.132만원
# 2021-02-17 : SELL 044480 -> 매도 금액 : 143.836만원, 전날 대비 상승률 0.08857808857808869:, 이익금 : 11.704만원, 현재 자산 : 143.96만원
#
# 2021-02-18 : BUY 051980 -> 911주 구입, 매수 금액: 143.938만원
# 2021-02-19 : SELL 051980 -> 매도 금액 : 168.535만원, 전날 대비 상승률 0.1708860759493671:, 이익금 : 24.597만원, 현재 자산 : 168.55만원
#
# 2021-02-22 : BUY 086900 -> 8주 구입, 매수 금액: 151.1448만원
# 2021-02-23 : SELL 086900 -> 매도 금액 : 143.572만원, 전날 대비 상승률 -0.05010294763696799:, 이익금 : -7.5728만원, 현재 자산 : 160.98만원
#
# 2021-03-02 : BUY 065680 -> 64주 구입, 매수 금액: 160.64만원
# 2021-03-03 : SELL 065680 -> 매도 금액 : 159.04만원, 전날 대비 상승률 -0.009960159362549792:, 이익금 : -1.6만원, 현재 자산 : 159.38만원
#
# 2021-03-08 : BUY 009620 -> 1306주 구입, 매수 금액: 159.332만원
# 2021-03-09 : SELL 009620 -> 매도 금액 : 165.209만원, 전날 대비 상승률 0.03688524590163933:, 이익금 : 5.877만원, 현재 자산 : 165.26만원
#
# 2021-03-11 : BUY 049080 -> 1010주 구입, 매수 금액: 165.135만원
# 2021-03-12 : SELL 049080 -> 매도 금액 : 171.7만원, 전날 대비 상승률 0.039755351681957096:, 이익금 : 6.565만원, 현재 자산 : 171.82만원
#
# 2021-03-17 : BUY 019490 -> 159주 구입, 매수 금액: 170.925만원
# 2021-03-18 : SELL 019490 -> 매도 금액 : 168.54만원, 전날 대비 상승률 -0.013953488372092981:, 이익금 : -2.385만원, 현재 자산 : 169.44만원
#
# 2021-03-25 : BUY 064090 -> 467주 구입, 매수 금액: 169.4276만원
# 2021-03-26 : SELL 064090 -> 매도 금액 : 192.9644만원, 전날 대비 상승률 0.1389195148842337:, 이익금 : 23.5368만원, 현재 자산 : 192.97만원
#
# 2021-03-26 : BUY 065500 -> 292주 구입, 매수 금액: 96.4476만원
# 2021-03-26 : BUY 064090 -> 233주 구입, 매수 금액: 96.2756만원
# 2021-03-29 : SELL 065500 -> 매도 금액 : 109.2664만원, 전날 대비 상승률 0.13290947623372684:, 이익금 : 12.8188만원, 현재 자산 : 109.52만원
# 2021-03-29 : SELL 064090 -> 매도 금액 : 90.404만원, 전날 대비 상승률 -0.06098741529525653:, 이익금 : -5.8716만원, 현재 자산 : 199.92만원
#
# 2021-04-01 : BUY 224060 -> 7809주 구입, 매수 금액: 199.9104만원
# 2021-04-02 : SELL 224060 -> 매도 금액 : 203.8149만원, 전날 대비 상승률 0.01953125:, 이익금 : 3.9045만원, 현재 자산 : 203.83만원
# 2021-04-16 : BUY 084110 -> 41주 구입, 매수 금액: 202.5892만원
# 2021-04-19 : SELL 084110 -> 매도 금액 : 205.328만원, 전날 대비 상승률 0.013518983242936988:, 이익금 : 2.7388만원, 현재 자산 : 206.57만원
#
# 2021-05-18 : BUY 139670 -> 73주 구입, 매수 금액: 204.4만원
# 2021-05-20 : SELL 139670 -> 매도 금액 : 163.885만원, 전날 대비 상승률 -0.19821428571428568:, 이익금 : -40.515만원, 현재 자산 : 166.05만원
#
# 2021-05-26 : BUY 139670 -> 38주 구입, 매수 금액: 81.7만원
# 2021-05-26 : BUY 032860 -> 93주 구입, 매수 금액: 82.305만원
# 2021-05-27 : SELL 139670 -> 매도 금액 : 78.09만원, 전날 대비 상승률 -0.04418604651162794:, 이익금 : -3.61만원, 현재 자산 : 80.14만원
# 2021-05-27 : SELL 032860 -> 매도 금액 : 86.49만원, 전날 대비 상승률 0.05084745762711873:, 이익금 : 4.185만원, 현재 자산 : 166.63만원
#
# 2021-05-27 : BUY 100220 -> 151주 구입, 매수 금액: 166.1만원
# 2021-05-28 : SELL 100220 -> 매도 금액 : 163.08만원, 전날 대비 상승률 -0.018181818181818188:, 이익금 : -3.02만원, 현재 자산 : 163.61만원
#
# 2021-06-01 : BUY 101390 -> 133주 구입, 매수 금액: 163.5368만원
# 2021-06-02 : SELL 101390 -> 매도 금액 : 178.9515만원, 전날 대비 상승률 0.09425829538061148:, 이익금 : 15.4147만원, 현재 자산 : 179.02만원
#
# 2021-06-02 : BUY 101390 -> 133주 구입, 매수 금액: 178.9515만원
# 2021-06-03 : SELL 101390 -> 매도 금액 : 196.3745만원, 전날 대비 상승률 0.0973615756224453:, 이익금 : 17.423만원, 현재 자산 : 196.44만원
#
# 2021-06-03 : BUY 101390 -> 133주 구입, 매수 금액: 196.3745만원
# 2021-06-04 : SELL 101390 -> 매도 금액 : 197.0395만원, 전날 대비 상승률 0.0033863867253640656:, 이익금 : 0.665만원, 현재 자산 : 197.11만원
#
# 2021-06-29 : BUY 121850 -> 621주 구입, 매수 금액: 196.857만원
# 2021-06-30 : SELL 121850 -> 매도 금액 : 201.5145만원, 전날 대비 상승률 0.023659305993690927:, 이익금 : 4.6575만원, 현재 자산 : 201.77만원
#
# 2021-07-01 : BUY 078650 -> 53주 구입, 매수 금액: 200.6951만원
# 2021-07-02 : SELL 078650 -> 매도 금액 : 181.578만원, 전날 대비 상승률 -0.09525444318271847:, 이익금 : -19.1171만원, 현재 자산 : 182.65만원
#
# 2021-07-14 : BUY 004830 -> 106주 구입, 매수 금액: 181.79만원
# 2021-07-15 : SELL 004830 -> 매도 금액 : 178.61만원, 전날 대비 상승률 -0.017492711370262426:, 이익금 : -3.18만원, 현재 자산 : 179.47만원
#
# 2021-08-19 : BUY 065440 -> 534주 구입, 매수 금액: 179.424만원
# 2021-08-20 : SELL 065440 -> 매도 금액 : 166.608만원, 전날 대비 상승률 -0.0714285714285714:, 이익금 : -12.816만원, 현재 자산 : 166.65만원
#
# 2021-08-20 : BUY 065440 -> 534주 구입, 매수 금액: 166.608만원
# 2021-08-23 : SELL 065440 -> 매도 금액 : 165.006만원, 전날 대비 상승률 -0.009615384615384581:, 이익금 : -1.602만원, 현재 자산 : 165.05만원
#
# 2021-08-27 : BUY 093640 -> 353주 구입, 매수 금액: 164.851만원
# 2021-08-30 : SELL 093640 -> 매도 금액 : 166.7925만원, 전날 대비 상승률 0.01177730192719495:, 이익금 : 1.9415만원, 현재 자산 : 166.99만원
#
# 2021-09-14 : BUY 042040 -> 1098주 구입, 매수 금액: 166.896만원
# 2021-09-15 : SELL 042040 -> 매도 금액 : 165.249만원, 전날 대비 상승률 -0.009868421052631526:, 이익금 : -1.647만원, 현재 자산 : 165.35만원
#
# 2021-09-24 : BUY 042040 -> 1036주 구입, 매수 금액: 165.242만원
# 2021-09-27 : SELL 042040 -> 매도 금액 : 155.4만원, 전날 대비 상승률 -0.059561128526645746:, 이익금 : -9.842만원, 현재 자산 : 155.50만원
#
# 2021-09-27 : BUY 042040 -> 1036주 구입, 매수 금액: 155.4만원
# 2021-09-28 : SELL 042040 -> 매도 금액 : 150.738만원, 전날 대비 상승률 -0.030000000000000027:, 이익금 : -4.662만원, 현재 자산 : 150.84만원
#
# 2021-10-06 : BUY 033830 -> 506주 구입, 매수 금액: 75.394만원
# 2021-10-06 : BUY 020180 -> 521주 구입, 매수 금액: 75.2845만원
# 2021-10-07 : SELL 033830 -> 매도 금액 : 97.911만원, 전날 대비 상승률 0.29865771812080544:, 이익금 : 22.517만원, 현재 자산 : 98.07만원
# 2021-10-07 : SELL 020180 -> 매도 금액 : 79.713만원, 전날 대비 상승률 0.05882352941176472:, 이익금 : 4.4285만원, 현재 자산 : 177.79만원
#
# 2021-10-07 : BUY 020180 -> 1162주 구입, 매수 금액: 177.786만원
# 2021-10-08 : SELL 020180 -> 매도 금액 : 181.853만원, 전날 대비 상승률 0.02287581699346397:, 이익금 : 4.067만원, 현재 자산 : 181.85만원
#
# 2021-10-12 : BUY 020180 -> 1317주 구입, 매수 금액: 181.746만원
# 2021-10-13 : SELL 020180 -> 매도 금액 : 190.3065만원, 전날 대비 상승률 0.047101449275362306:, 이익금 : 8.5605만원, 현재 자산 : 190.41만원
#
# 2021-10-15 : BUY 185490 -> 73주 구입, 매수 금액: 189.435만원
# 2021-10-18 : SELL 185490 -> 매도 금액 : 178.85만원, 전날 대비 상승률 -0.055876685934489356:, 이익금 : -10.585만원, 현재 자산 : 179.83만원
#
# 2021-10-18 : BUY 185490 -> 73주 구입, 매수 금액: 178.85만원
# 2021-10-19 : SELL 185490 -> 매도 금액 : 179.945만원, 전날 대비 상승률 0.00612244897959191:, 이익금 : 1.095만원, 현재 자산 : 180.92만원
#
# 2021-10-25 : BUY 102280 -> 2298주 구입, 매수 금액: 180.8526만원
# 2021-10-26 : SELL 102280 -> 매도 금액 : 181.0824만원, 전날 대비 상승률 0.0012706480304955914:, 이익금 : 0.2298만원, 현재 자산 : 181.15만원
#
# 2021-10-28 : BUY 136510 -> 166주 구입, 매수 금액: 180.94만원
# 2021-10-29 : SELL 136510 -> 매도 금액 : 234.89만원, 전날 대비 상승률 0.298165137614679:, 이익금 : 53.95만원, 현재 자산 : 235.10만원
#
# 2021-11-05 : BUY 126600 -> 197주 구입, 매수 금액: 234.43만원
# 2021-11-08 : SELL 126600 -> 매도 금액 : 201.925만원, 전날 대비 상승률 -0.1386554621848739:, 이익금 : -32.505만원, 현재 자산 : 202.60만원
#
# 2021-12-07 : BUY 001140 -> 1205주 구입, 매수 금액: 202.44만원
# 2021-12-08 : SELL 001140 -> 매도 금액 : 206.6575만원, 전날 대비 상승률 0.02083333333333326:, 이익금 : 4.2175만원, 현재 자산 : 206.82만원
#
#  earning_rate : 206.8164
# 시작 금액 : 100.0 만원
#
# 2021-01-07 : BUY 045340 -> 67주 구입, 매수 금액: 99.495만원
# 2021-01-08 : SELL 045340 -> 매도 금액 : 102.51만원, 전날 대비 상승률 0.030303030303030276:, 이익금 : 3.015만원, 현재 자산 : 103.02만원
#
# 2021-01-26 : BUY 004560 -> 62주 구입, 매수 금액: 102.3만원
# 2021-01-27 : SELL 004560 -> 매도 금액 : 132.99만원, 전날 대비 상승률 0.30000000000000004:, 이익금 : 30.69만원, 현재 자산 : 133.71만원
#
# 2021-01-27 : BUY 214330 -> 403주 구입, 매수 금액: 133.5945만원
# 2021-01-28 : SELL 214330 -> 매도 금액 : 133.796만원, 전날 대비 상승률 0.0015082956259426794:, 이익금 : 0.2015만원, 현재 자산 : 133.91만원
#
# 2021-01-29 : BUY 023960 -> 284주 구입, 매수 금액: 133.906만원
# 2021-02-01 : SELL 023960 -> 매도 금액 : 146.26만원, 전날 대비 상승률 0.09225874867444328:, 이익금 : 12.354만원, 현재 자산 : 146.26만원
#
# 2021-02-15 : BUY 208640 -> 356주 구입, 매수 금액: 72.98만원
# 2021-02-15 : BUY 004140 -> 76주 구입, 매수 금액: 73.0968만원
# 2021-02-16 : SELL 208640 -> 매도 금액 : 70.666만원, 전날 대비 상승률 -0.03170731707317076:, 이익금 : -2.314만원, 현재 자산 : 70.85만원
# 2021-02-16 : SELL 004140 -> 매도 금액 : 94.9468만원, 전날 대비 상승률 0.29891869411520067:, 이익금 : 21.85만원, 현재 자산 : 165.80만원
#
# 2021-03-15 : BUY 053030 -> 102주 구입, 매수 금액: 164.73만원
# 2021-03-16 : SELL 053030 -> 매도 금액 : 201.96만원, 전날 대비 상승률 0.22600619195046434:, 이익금 : 37.23만원, 현재 자산 : 203.03만원
#
# 2021-03-23 : BUY 089530 -> 687주 구입, 매수 금액: 202.9398만원
# 2021-03-24 : SELL 089530 -> 매도 금액 : 207.4053만원, 전날 대비 상승률 0.022004062288422555:, 이익금 : 4.4655만원, 현재 자산 : 207.49만원
#
# 2021-03-25 : BUY 064090 -> 571주 구입, 매수 금액: 207.1588만원
# 2021-03-26 : SELL 064090 -> 매도 금액 : 235.9372만원, 전날 대비 상승률 0.1389195148842337:, 이익금 : 28.7784만원, 현재 자산 : 236.27만원
#
# 2021-03-26 : BUY 064090 -> 571주 구입, 매수 금액: 235.9372만원
# 2021-03-29 : SELL 064090 -> 매도 금액 : 221.548만원, 전날 대비 상승률 -0.06098741529525653:, 이익금 : -14.3892만원, 현재 자산 : 221.88만원
#
# 2021-03-29 : BUY 064090 -> 571주 구입, 매수 금액: 221.548만원
# 2021-03-30 : SELL 064090 -> 매도 금액 : 241.7043만원, 전날 대비 상승률 0.09097938144329887:, 이익금 : 20.1563만원, 현재 자산 : 242.04만원
#
# 2021-03-30 : BUY 065500 -> 534주 구입, 매수 금액: 241.635만원
# 2021-03-31 : SELL 065500 -> 매도 금액 : 280.2966만원, 전날 대비 상승률 0.15999999999999992:, 이익금 : 38.6616만원, 현재 자산 : 280.70만원
#
# 2021-04-01 : BUY 224060 -> 10964주 구입, 매수 금액: 280.6784만원
# 2021-04-02 : SELL 224060 -> 매도 금액 : 286.1604만원, 전날 대비 상승률 0.01953125:, 이익금 : 5.482만원, 현재 자산 : 286.18만원
#
# 2021-04-06 : BUY 096040 -> 5074주 구입, 매수 금액: 286.1736만원
# 2021-04-07 : SELL 096040 -> 매도 금액 : 283.6366만원, 전날 대비 상승률 -0.00886524822695034:, 이익금 : -2.537만원, 현재 자산 : 283.64만원
#
# 2021-05-11 : BUY 094170 -> 416주 구입, 매수 금액: 283.296만원
# 2021-05-12 : SELL 094170 -> 매도 금액 : 287.456만원, 전날 대비 상승률 0.014684287812041008:, 이익금 : 4.16만원, 현재 자산 : 287.80만원
#
# 2021-05-25 : BUY 032860 -> 422주 구입, 매수 금액: 287.382만원
# 2021-05-26 : SELL 032860 -> 매도 금액 : 373.47만원, 전날 대비 상승률 0.2995594713656389:, 이익금 : 86.088만원, 현재 자산 : 373.89만원
#
# 2021-05-26 : BUY 139670 -> 173주 구입, 매수 금액: 371.95만원
# 2021-05-27 : SELL 139670 -> 매도 금액 : 355.515만원, 전날 대비 상승률 -0.04418604651162794:, 이익금 : -16.435만원, 현재 자산 : 357.46만원
#
# 2021-05-31 : BUY 136510 -> 1548주 구입, 매수 금액: 357.2784만원
# 2021-06-01 : SELL 136510 -> 매도 금액 : 462.5424만원, 전날 대비 상승률 0.2946273830155979:, 이익금 : 105.264만원, 현재 자산 : 462.72만원
#
# 2021-06-01 : BUY 101390 -> 376주 구입, 매수 금액: 462.3296만원
# 2021-06-02 : SELL 101390 -> 매도 금액 : 505.908만원, 전날 대비 상승률 0.09425829538061148:, 이익금 : 43.5784만원, 현재 자산 : 506.30만원
#
# 2021-08-18 : BUY 950130 -> 281주 구입, 매수 금액: 505.8만원
# 2021-08-19 : SELL 950130 -> 매도 금액 : 477.7만원, 전날 대비 상승률 -0.05555555555555558:, 이익금 : -28.1만원, 현재 자산 : 478.20만원
#
# 2021-08-27 : BUY 093640 -> 1023주 구입, 매수 금액: 477.741만원
# 2021-08-30 : SELL 093640 -> 매도 금액 : 483.3675만원, 전날 대비 상승률 0.01177730192719495:, 이익금 : 5.6265만원, 현재 자산 : 483.83만원
#
# 2021-09-09 : BUY 042040 -> 2829주 구입, 매수 금액: 483.759만원
# 2021-09-10 : SELL 042040 -> 매도 금액 : 485.1735만원, 전날 대비 상승률 0.0029239766081872176:, 이익금 : 1.4145만원, 현재 자산 : 485.24만원
#
# 2021-09-24 : BUY 042040 -> 3042주 구입, 매수 금액: 485.199만원
# 2021-09-27 : SELL 042040 -> 매도 금액 : 456.3만원, 전날 대비 상승률 -0.059561128526645746:, 이익금 : -28.899만원, 현재 자산 : 456.34만원
#
# 2021-10-06 : BUY 208710 -> 786주 구입, 매수 금액: 227.94만원
# 2021-10-06 : BUY 020180 -> 1579주 구입, 매수 금액: 228.1655만원
# 2021-10-07 : SELL 208710 -> 매도 금액 : 258.594만원, 전날 대비 상승률 0.1344827586206896:, 이익금 : 30.654만원, 현재 자산 : 258.83만원
# 2021-10-07 : SELL 020180 -> 매도 금액 : 241.587만원, 전날 대비 상승률 0.05882352941176472:, 이익금 : 13.4215만원, 현재 자산 : 500.42만원
# 2021-10-07 : BUY 002290 -> 442주 구입, 매수 금액: 250.172만원
# 2021-10-07 : BUY 020180 -> 1635주 구입, 매수 금액: 250.155만원
# 2021-10-08 : SELL 002290 -> 매도 금액 : 254.15만원, 전날 대비 상승률 0.01590106007067127:, 이익금 : 3.978만원, 현재 자산 : 254.24만원
# 2021-10-08 : SELL 020180 -> 매도 금액 : 255.8775만원, 전날 대비 상승률 0.02287581699346397:, 이익금 : 5.7225만원, 현재 자산 : 510.12만원
#
# 2021-10-08 : BUY 208710 -> 1667주 구입, 매수 금액: 510.102만원
# 2021-10-12 : SELL 208710 -> 매도 금액 : 514.2695만원, 전날 대비 상승률 0.008169934640522847:, 이익금 : 4.1675만원, 현재 자산 : 514.28만원
#
# 2021-10-12 : BUY 002290 -> 508주 구입, 매수 금액: 257.048만원
# 2021-10-12 : BUY 020180 -> 1863주 구입, 매수 금액: 257.094만원
# 2021-10-13 : SELL 002290 -> 매도 금액 : 259.588만원, 전날 대비 상승률 0.009881422924901129:, 이익금 : 2.54만원, 현재 자산 : 259.73만원
# 2021-10-13 : SELL 020180 -> 매도 금액 : 269.2035만원, 전날 대비 상승률 0.047101449275362306:, 이익금 : 12.1095만원, 현재 자산 : 528.93만원
#
# 2021-10-15 : BUY 185490 -> 203주 구입, 매수 금액: 526.785만원
# 2021-10-18 : SELL 185490 -> 매도 금액 : 497.35만원, 전날 대비 상승률 -0.055876685934489356:, 이익금 : -29.435만원, 현재 자산 : 499.50만원
#
# 2021-10-18 : BUY 185490 -> 203주 구입, 매수 금액: 497.35만원
# 2021-10-19 : SELL 185490 -> 매도 금액 : 500.395만원, 전날 대비 상승률 0.00612244897959191:, 이익금 : 3.045만원, 현재 자산 : 502.54만원
#
# 2021-10-28 : BUY 136510 -> 461주 구입, 매수 금액: 502.49만원
# 2021-10-29 : SELL 136510 -> 매도 금액 : 652.315만원, 전날 대비 상승률 0.298165137614679:, 이익금 : 149.825만원, 현재 자산 : 652.37만원
#
# 2021-11-05 : BUY 025550 -> 1376주 구입, 매수 금액: 652.224만원
# 2021-11-08 : SELL 025550 -> 매도 금액 : 619.888만원, 전날 대비 상승률 -0.04957805907172996:, 이익금 : -32.336만원, 현재 자산 : 620.03만원
#
# 2021-11-09 : BUY 060560 -> 4960주 구입, 매수 금액: 620.0만원
# 2021-11-10 : SELL 060560 -> 매도 금액 : 624.96만원, 전날 대비 상승률 0.008000000000000007:, 이익금 : 4.96만원, 현재 자산 : 624.99만원
#
# 2021-11-11 : BUY 134580 -> 1066주 구입, 매수 금액: 624.676만원
# 2021-11-12 : SELL 134580 -> 매도 금액 : 811.226만원, 전날 대비 상승률 0.2986348122866893:, 이익금 : 186.55만원, 현재 자산 : 811.54만원
#
# 2021-11-26 : BUY 078650 -> 1462주 구입, 매수 금액: 811.41만원
# 2021-11-29 : SELL 078650 -> 매도 금액 : 865.504만원, 전날 대비 상승률 0.06666666666666665:, 이익금 : 54.094만원, 현재 자산 : 865.64만원
#
#  earning_rate : 865.6375
# 시작 금액 : 100.0 만원
#
# 2021-01-07 : BUY 011080 -> 581주 구입, 매수 금액: 99.932만원
# 2021-01-08 : SELL 011080 -> 매도 금액 : 100.8035만원, 전날 대비 상승률 0.008720930232558155:, 이익금 : 0.8715만원, 현재 자산 : 100.87만원
#
# 2021-01-18 : BUY 204840 -> 533주 구입, 매수 금액: 100.737만원
# 2021-01-19 : SELL 204840 -> 매도 금액 : 86.0795만원, 전날 대비 상승률 -0.14550264550264547:, 이익금 : -14.6575만원, 현재 자산 : 86.21만원
#
# 2021-01-20 : BUY 054780 -> 48주 구입, 매수 금액: 85.44만원
# 2021-01-21 : SELL 054780 -> 매도 금액 : 87.36만원, 전날 대비 상승률 0.022471910112359605:, 이익금 : 1.92만원, 현재 자산 : 88.13만원
#
# 2021-01-26 : BUY 004560 -> 53주 구입, 매수 금액: 87.45만원
# 2021-01-27 : SELL 004560 -> 매도 금액 : 113.685만원, 전날 대비 상승률 0.30000000000000004:, 이익금 : 26.235만원, 현재 자산 : 114.37만원
#
# 2021-01-27 : BUY 214330 -> 345주 구입, 매수 금액: 114.3675만원
# 2021-01-28 : SELL 214330 -> 매도 금액 : 114.54만원, 전날 대비 상승률 0.0015082956259426794:, 이익금 : 0.1725만원, 현재 자산 : 114.54만원
#
# 2021-01-29 : BUY 071670 -> 64주 구입, 매수 금액: 113.92만원
# 2021-02-01 : SELL 071670 -> 매도 금액 : 117.12만원, 전날 대비 상승률 0.028089887640449396:, 이익금 : 3.2만원, 현재 자산 : 117.74만원
#
# 2021-02-15 : BUY 208640 -> 143주 구입, 매수 금액: 29.315만원
# 2021-02-15 : BUY 036030 -> 24주 구입, 매수 금액: 28.8만원
# 2021-02-15 : BUY 009070 -> 47주 구입, 매수 금액: 28.905만원
# 2021-02-15 : BUY 004140 -> 30주 구입, 매수 금액: 28.854만원
# 2021-02-16 : SELL 208640 -> 매도 금액 : 28.3855만원, 전날 대비 상승률 -0.03170731707317076:, 이익금 : -0.9295만원, 현재 자산 : 30.25만원
# 2021-02-16 : SELL 036030 -> 매도 금액 : 37.44만원, 전날 대비 상승률 0.30000000000000004:, 이익금 : 8.64만원, 현재 자산 : 67.69만원
# 2021-02-16 : SELL 009070 -> 매도 금액 : 37.553만원, 전날 대비 상승률 0.2991869918699186:, 이익금 : 8.648만원, 현재 자산 : 105.25만원
# 2021-02-16 : SELL 004140 -> 매도 금액 : 37.479만원, 전날 대비 상승률 0.29891869411520067:, 이익금 : 8.625만원, 현재 자산 : 142.72만원
#
# 2021-03-12 : BUY 006200 -> 822주 구입, 매수 금액: 142.617만원
# 2021-03-15 : SELL 006200 -> 매도 금액 : 129.054만원, 전날 대비 상승률 -0.09510086455331412:, 이익금 : -13.563만원, 현재 자산 : 129.16만원
#
# 2021-03-23 : BUY 089530 -> 437주 구입, 매수 금액: 129.0898만원
# 2021-03-24 : SELL 089530 -> 매도 금액 : 131.9303만원, 전날 대비 상승률 0.022004062288422555:, 이익금 : 2.8405만원, 현재 자산 : 132.00만원
#
# 2021-03-24 : BUY 065500 -> 354주 구입, 매수 금액: 131.6526만원
# 2021-03-25 : SELL 065500 -> 매도 금액 : 125.7408만원, 전날 대비 상승률 -0.04490454423232049:, 이익금 : -5.9118만원, 현재 자산 : 126.09만원
#
# 2021-03-29 : BUY 064090 -> 324주 구입, 매수 금액: 125.712만원
# 2021-03-30 : SELL 064090 -> 매도 금액 : 137.1492만원, 전날 대비 상승률 0.09097938144329887:, 이익금 : 11.4372만원, 현재 자산 : 137.53만원
#
# 2021-03-30 : BUY 065500 -> 151주 구입, 매수 금액: 68.3275만원
# 2021-03-30 : BUY 064090 -> 162주 구입, 매수 금액: 68.5746만원
# 2021-03-31 : SELL 065500 -> 매도 금액 : 79.2599만원, 전날 대비 상승률 0.15999999999999992:, 이익금 : 10.9324만원, 현재 자산 : 79.89만원
# 2021-03-31 : SELL 064090 -> 매도 금액 : 64.2816만원, 전날 대비 상승률 -0.06260335459485:, 이익금 : -4.293만원, 현재 자산 : 144.17만원
#
# 2021-04-13 : BUY 038620 -> 1021주 구입, 매수 금액: 144.0631만원
# 2021-04-14 : SELL 038620 -> 매도 금액 : 186.9451만원, 전날 대비 상승률 0.297661233167966:, 이익금 : 42.882만원, 현재 자산 : 187.05만원
#
# 2021-04-23 : BUY 003530 -> 364주 구입, 매수 금액: 186.732만원
# 2021-04-26 : SELL 003530 -> 매도 금액 : 190.372만원, 전날 대비 상승률 0.01949317738791434:, 이익금 : 3.64만원, 현재 자산 : 190.69만원
#
# 2021-04-26 : BUY 208640 -> 556주 구입, 매수 금액: 190.43만원
# 2021-04-27 : SELL 208640 -> 매도 금액 : 184.314만원, 전날 대비 상승률 -0.03211678832116793:, 이익금 : -6.116만원, 현재 자산 : 184.57만원
#
# 2021-05-03 : BUY 019170 -> 30주 구입, 매수 금액: 183.9만원
# 2021-05-04 : SELL 019170 -> 매도 금액 : 180.6만원, 전날 대비 상승률 -0.01794453507340943:, 이익금 : -3.3만원, 현재 자산 : 181.27만원
#
# 2021-05-06 : BUY 002690 -> 403주 구입, 매수 금액: 181.2694만원
# 2021-05-07 : SELL 002690 -> 매도 금액 : 201.5806만원, 전날 대비 상승률 0.11204979991107167:, 이익금 : 20.3112만원, 현재 자산 : 201.58만원
#
# 2021-05-21 : BUY 024940 -> 174주 구입, 매수 금액: 200.97만원
# 2021-05-24 : SELL 024940 -> 매도 금액 : 224.46만원, 전날 대비 상승률 0.11688311688311681:, 이익금 : 23.49만원, 현재 자산 : 225.07만원
#
# 2021-05-25 : BUY 101390 -> 71주 구입, 매수 금액: 111.9883만원
# 2021-05-25 : BUY 032860 -> 165주 구입, 매수 금액: 112.365만원
# 2021-05-26 : SELL 101390 -> 매도 금액 : 116.9938만원, 전날 대비 상승률 0.04469663348760533:, 이익금 : 5.0055만원, 현재 자산 : 117.72만원
# 2021-05-26 : SELL 032860 -> 매도 금액 : 146.025만원, 전날 대비 상승률 0.2995594713656389:, 이익금 : 33.66만원, 현재 자산 : 263.74만원
#
# 2021-05-26 : BUY 032860 -> 298주 구입, 매수 금액: 263.73만원
# 2021-05-27 : SELL 032860 -> 매도 금액 : 277.14만원, 전날 대비 상승률 0.05084745762711873:, 이익금 : 13.41만원, 현재 자산 : 277.15만원
#
# 2021-05-31 : BUY 009620 -> 461주 구입, 매수 금액: 138.3만원
# 2021-05-31 : BUY 136510 -> 600주 구입, 매수 금액: 138.48만원
# 2021-06-01 : SELL 009620 -> 매도 금액 : 149.825만원, 전날 대비 상승률 0.08333333333333326:, 이익금 : 11.525만원, 현재 자산 : 150.19만원
# 2021-06-01 : SELL 136510 -> 매도 금액 : 179.28만원, 전날 대비 상승률 0.2946273830155979:, 이익금 : 40.8만원, 현재 자산 : 329.48만원
#
# 2021-06-11 : BUY 196700 -> 448주 구입, 매수 금액: 328.832만원
# 2021-06-14 : SELL 196700 -> 매도 금액 : 407.232만원, 전날 대비 상승률 0.23841961852861027:, 이익금 : 78.4만원, 현재 자산 : 407.88만원
#
# 2021-06-28 : BUY 185490 -> 102주 구입, 매수 금액: 405.45만원
# 2021-06-29 : SELL 185490 -> 매도 금액 : 399.33만원, 전날 대비 상승률 -0.015094339622641506:, 이익금 : -6.12만원, 현재 자산 : 401.75만원
#
# 2021-06-29 : BUY 121850 -> 1267주 구입, 매수 금액: 401.639만원
# 2021-06-30 : SELL 121850 -> 매도 금액 : 411.1415만원, 전날 대비 상승률 0.023659305993690927:, 이익금 : 9.5025만원, 현재 자산 : 411.26만원
#
# 2021-07-02 : BUY 121850 -> 686주 구입, 매수 금액: 205.457만원
# 2021-07-02 : BUY 078650 -> 60주 구입, 매수 금액: 205.56만원
# 2021-07-05 : SELL 121850 -> 매도 금액 : 206.486만원, 전날 대비 상승률 0.005008347245408995:, 이익금 : 1.029만원, 현재 자산 : 206.73만원
# 2021-07-05 : SELL 078650 -> 매도 금액 : 228.552만원, 전날 대비 상승률 0.11185055458260362:, 이익금 : 22.992만원, 현재 자산 : 435.28만원
#
# 2021-07-06 : BUY 189860 -> 489주 구입, 매수 금액: 434.721만원
# 2021-07-07 : SELL 189860 -> 매도 금액 : 476.286만원, 전날 대비 상승률 0.0956130483689539:, 이익금 : 41.565만원, 현재 자산 : 476.84만원
#
# 2021-08-19 : BUY 078650 -> 302주 구입, 매수 금액: 476.4956만원
# 2021-08-20 : SELL 078650 -> 매도 금액 : 423.404만원, 전날 대비 상승률 -0.11142096590188866:, 이익금 : -53.0916만원, 현재 자산 : 423.75만원
#
# 2021-08-24 : BUY 028080 -> 599주 구입, 매수 금액: 423.493만원
# 2021-08-25 : SELL 028080 -> 매도 금액 : 408.518만원, 전날 대비 상승률 -0.03536067892503536:, 이익금 : -14.975만원, 현재 자산 : 408.78만원
#
# 2021-08-27 : BUY 093640 -> 875주 구입, 매수 금액: 408.625만원
# 2021-08-30 : SELL 093640 -> 매도 금액 : 413.4375만원, 전날 대비 상승률 0.01177730192719495:, 이익금 : 4.8125만원, 현재 자산 : 413.59만원
#
# 2021-09-27 : BUY 013360 -> 631주 구입, 매수 금액: 413.305만원
# 2021-09-28 : SELL 013360 -> 매도 금액 : 372.29만원, 전날 대비 상승률 -0.0992366412213741:, 이익금 : -41.015만원, 현재 자산 : 372.57만원
#
# 2021-09-28 : BUY 053050 -> 1385주 구입, 매수 금액: 372.565만원
# 2021-09-29 : SELL 053050 -> 매도 금액 : 397.495만원, 전날 대비 상승률 0.06691449814126393:, 이익금 : 24.93만원, 현재 자산 : 397.50만원
#
# 2021-10-12 : BUY 032280 -> 588주 구입, 매수 금액: 397.488만원
# 2021-10-13 : SELL 032280 -> 매도 금액 : 439.236만원, 전날 대비 상승률 0.1050295857988166:, 이익금 : 41.748만원, 현재 자산 : 439.25만원
# 2021-10-18 : BUY 025890 -> 808주 구입, 매수 금액: 438.744만원
# 2021-10-19 : SELL 025890 -> 매도 금액 : 438.744만원, 전날 대비 상승률 0.0:, 이익금 : 0.0만원, 현재 자산 : 439.25만원
#
# 2021-10-28 : BUY 136510 -> 402주 구입, 매수 금액: 438.18만원
# 2021-10-29 : SELL 136510 -> 매도 금액 : 568.83만원, 전날 대비 상승률 0.298165137614679:, 이익금 : 130.65만원, 현재 자산 : 569.90만원
#
# 2021-10-29 : BUY 136510 -> 402주 구입, 매수 금액: 568.83만원
# 2021-11-01 : SELL 136510 -> 매도 금액 : 669.33만원, 전날 대비 상승률 0.1766784452296819:, 이익금 : 100.5만원, 현재 자산 : 670.40만원
#
# 2021-11-05 : BUY 126600 -> 563주 구입, 매수 금액: 669.97만원
# 2021-11-08 : SELL 126600 -> 매도 금액 : 577.075만원, 전날 대비 상승률 -0.1386554621848739:, 이익금 : -92.895만원, 현재 자산 : 577.51만원
#
# 2021-11-10 : BUY 136510 -> 118주 구입, 매수 금액: 575.84만원
# 2021-11-11 : SELL 136510 -> 매도 금액 : 748.12만원, 전날 대비 상승률 0.2991803278688525:, 이익금 : 172.28만원, 현재 자산 : 749.79만원
#
# 2021-11-12 : BUY 032280 -> 2808주 구입, 매수 금액: 749.736만원
# 2021-11-15 : SELL 032280 -> 매도 금액 : 755.352만원, 전날 대비 상승률 0.0074906367041198685:, 이익금 : 5.616만원, 현재 자산 : 755.40만원
#
# 2021-11-30 : BUY 017000 -> 131주 구입, 매수 금액: 187.985만원
# 2021-11-30 : BUY 136510 -> 117주 구입, 매수 금액: 188.37만원
# 2021-11-30 : BUY 029480 -> 1414주 구입, 매수 금액: 188.769만원
# 2021-11-30 : BUY 010690 -> 251주 구입, 매수 금액: 188.25만원
# 2021-12-01 : SELL 017000 -> 매도 금액 : 184.055만원, 전날 대비 상승률 -0.020905923344947785:, 이익금 : -3.93만원, 현재 자산 : 186.08만원
# 2021-12-01 : SELL 136510 -> 매도 금액 : 171.405만원, 전날 대비 상승률 -0.09006211180124224:, 이익금 : -16.965만원, 현재 자산 : 357.49만원
# 2021-12-01 : SELL 029480 -> 매도 금액 : 190.183만원, 전날 대비 상승률 0.0074906367041198685:, 이익금 : 1.414만원, 현재 자산 : 547.67만원
# 2021-12-01 : SELL 010690 -> 매도 금액 : 202.808만원, 전날 대비 상승률 0.07733333333333325:, 이익금 : 14.558만원, 현재 자산 : 750.48만원
#
# 2021-12-07 : BUY 101730 -> 168주 구입, 매수 금액: 749.28만원
# 2021-12-08 : SELL 101730 -> 매도 금액 : 776.16만원, 전날 대비 상승률 0.03587443946188351:, 이익금 : 26.88만원, 현재 자산 : 777.36만원
#
# 2021-12-14 : BUY 121850 -> 3007주 구입, 매수 금액: 777.3095만원
# 2021-12-15 : SELL 121850 -> 매도 금액 : 1010.352만원, 전날 대비 상승률 0.299806576402321:, 이익금 : 233.0425만원, 현재 자산 : 1010.40만원
#
#  earning_rate : 1010.4029

# %%
from functools import reduce

scaling1_simul_df = pd.DataFrame(scaling1_simul, columns=['sell_date', 'money'])
scaling2_simul_df = pd.DataFrame(scaling2_simul, columns=['sell_date', 'money'])
scaling3_simul_df = pd.DataFrame(scaling3_simul, columns=['sell_date', 'money'])
scaling4_simul_df = pd.DataFrame(scaling4_simul, columns=['sell_date', 'money'])

dfs = [scaling1_simul_df, scaling2_simul_df, scaling3_simul_df, scaling4_simul_df]

# 4개의 df를 한번에 merge하기
df_merge = reduce(lambda left, right: pd.merge(left, right, on='sell_date', how='outer',sort=True), dfs)


df_merge.columns=['sell_date', 'scaling1', 'scaling2', 'scaling3', 'scaling4']
df_merge

first_data = {
    'sell_date' : '2021-01-04', 
    'scaling1' : 1000000, 
    'scaling2' : 1000000, 
    'scaling3' : 1000000, 
    'scaling4' : 1000000
}

df_merge = df_merge.append(first_data, ignore_index=True)

df_merge = df_merge.sort_values(by=['sell_date'], axis=0).reset_index()
del df_merge['index']
df_merge = df_merge.fillna(method='ffill')

# %%
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(15,8))

plt.plot(df_merge['scaling1'], label='scaling1')
plt.plot(df_merge['scaling2'], label='scaling2')
plt.plot(df_merge['scaling3'], label='scaling3')
plt.plot(df_merge['scaling4'], label='scaling4')
plt.legend()

# %%
range(0,80, 10)
# Out:
# range(0, 80, 10)

# %%
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(15,10))
sns.lineplot(data = df_merge, x="sell_date", y = "scaling1", label='scaling1')
sns.lineplot(data = df_merge, x="sell_date", y = "scaling2", label='scaling2')
sns.lineplot(data = df_merge, x="sell_date", y = "scaling3", label='scaling3')
sns.lineplot(data = df_merge, x="sell_date", y = "scaling4", label='scaling4')
_=plt.xticks(range(0,81, 8))
_=plt.yticks()

# %% [markdown]
# \frac{abc}{def}
